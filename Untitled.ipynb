# %% [markdown]
# <a href="https://colab.research.google.com/github/gkaleeswari/mini-project-/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("/content/Mini Project - Marks Adding.csv")
data
# Out:
#        Roll Num  Marks
# 0     102003542      1
# 1     102003640      1
# 2     102003725      1
# 3     102003307      1
# 4     102003458      1
# ...         ...    ...
# 1831  102003755      1
# 1832  102017147      1
# 1833  102017152      1
# 1834  102003451      1
# 1835  102003549      1
#
# [1836 rows x 2 columns]

# %%
import csv
from collections import defaultdict

def sum_marks(input_filename, output_filename):
    marks_dict = defaultdict(int)


    try:
        with open(input_filename, mode='r') as infile:
            reader = csv.reader(infile)
            next(reader)
            for row in reader:
                roll_num, marks = row
                marks_dict[roll_num] += int(marks)
    except FileNotFoundError:
        print(f"Error: The file {input_filename} was not found.")
        return

    with open(output_filename, mode='w', newline='') as outfile:
        writer = csv.writer(outfile)
        writer.writerow(['Roll Num', 'Marks'])
        for roll_num, total_marks in marks_dict.items():
            writer.writerow([roll_num, total_marks])

    print(f'Output written to {output_filename}')

input_filename = 'Mini Project - Marks Adding.csv'
output_filename = 'output.csv'

sum_marks(input_filename, output_filename)
# Out:
# Output written to output.csv
